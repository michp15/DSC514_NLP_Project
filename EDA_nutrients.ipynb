# %% [markdown]
# # DATASET LOADING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import numpy as np
import re

# %%
data = pd.read_csv("data_with_nutrients_final.csv")
data.head(20)["ingredients"]
# Out:
# 0     ["6 cups rice krispies", "2 cups reese's peanu...
# 1     ["4 boneless skinless chicken breasts", "6 spr...
# 2     ["1 (7 1/2 ounce) can refrigerated biscuits", ...
# 3     ["2 pounds ground beef or turkey", "2 pounds r...
# 4     ["3 lbs beef round steak", "all-purpose flour"...
# 5     ["6 oz. evaporated milk", "1 3/4 sticks butter...
# 6     ["3 ripe avocados", "2 tbsp. lemon juice", "1/...
# 7     ["1 tsp. cornstarch", "2 tbs. low-sodium soy s...
# 8     ["1 small red apple", "1 tbsp water", "1 tsp g...
# 9     ["1 box duncan hines family size brownie mix",...
# 10    ["1 large (24 oz.) carton 1% cottage cheese", ...
# 11    ["1 c. mayonnaise", "1 c. sour cream", "1 tsp....
# 12    ["2/3 cup light sour cream", "4 teaspoons hone...
# 13    ["1/2 pound whole-wheat rotini", "4 tablespoon...
# 14    ["1 large sweet potato, uniform in shape", "1 ...
# 15          ["1 egg 3/4 cup sugar 1 cup peanut butter"]
# 16    ["1 (12 ounce) package egg noodles", "1 14 cup...
# 17    ["1 spaghetti squash (about 3 lbs.)", "2 cups ...
# 18    ["3 oranges", "3/4 cup water", "1/2 cup long-g...
# 19    ["3 lbs small red potatoes (peeled or unpeeled...
# Name: ingredients, dtype: object

# %%
data.columns
# Out:
# Index(['ingredients', 'directions', 'NER', 'ingredients_count', 'NER_count',
#        'directions_count', 'normalized_ingredients', 'normalized_directions',
#        'calories', 'protein_g', 'carbs_g', 'fat_g', 'fiber_g', 'sugar_g'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# ingredients               0
# directions                0
# NER                       0
# ingredients_count         0
# NER_count                 0
# directions_count          0
# normalized_ingredients    0
# normalized_directions     0
# calories                  0
# protein_g                 0
# carbs_g                   0
# fat_g                     0
# fiber_g                   0
# sugar_g                   0
# dtype: int64

# %%
nut = data[["calories", "protein_g", "carbs_g", "fat_g", "fiber_g", "sugar_g"]]
nut.head()
# Out:
#    calories  protein_g  carbs_g  fat_g  fiber_g  sugar_g
# 0    5950.0       85.0    750.0  300.0     25.0    480.0
# 1    2600.0      280.0    280.0   60.0     40.0     50.0
# 2    2800.0       25.0    300.0  180.0     15.0    200.0
# 3    5700.0      500.0    400.0  250.0    100.0    100.0
# 4    3500.0      400.0     80.0  150.0     10.0     30.0

# %%
nut.corr(method = "pearson")
# Out:
#            calories  protein_g   carbs_g     fat_g   fiber_g   sugar_g
# calories   1.000000   0.459056  0.750330  0.888036  0.390062  0.558214
# protein_g  0.459056   1.000000 -0.018033  0.415646  0.329729 -0.200284
# carbs_g    0.750330  -0.018033  1.000000  0.437934  0.369246  0.846396
# fat_g      0.888036   0.415646  0.437934  1.000000  0.246661  0.309742
# fiber_g    0.390062   0.329729  0.369246  0.246661  1.000000  0.111684
# sugar_g    0.558214  -0.200284  0.846396  0.309742  0.111684  1.000000

# %% [markdown]
# # Plain correlation with ingredients, didn't use the amounts for each recipe

# %%
ner = data["NER"].apply(ast.literal_eval)
ner.iloc[0]
# Out:
# ['rice krispies',
#  'miniatures',
#  'marshmallows',
#  '¼',
#  'chocolate chips',
#  'smooth peanut butter']

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()
ing_onehot = pd.DataFrame(
    mlb.fit_transform(ner),
    columns=mlb.classes_,
    index=data.index
)
ing_numeric = ing_onehot

# %%
ingredient_list = ner.explode()
top_ingredients = ingredient_list.value_counts().head(50)
common = [col for col in ing_numeric.columns if col in top_ingredients.index]
subset = ing_numeric[common]

# %%
for nutrient_column in nut.columns:
    nutrient = nut[nutrient_column]
    ingredient_corr = subset.apply(lambda x: x.corr(nutrient))

    top_pos_corr = ingredient_corr.sort_values(ascending = False).head(10)
    top_neg_corr = ingredient_corr.sort_values(ascending = True).head(10)

    print(f"Top 10 positively correlated ingredients with {nutrient_column}:")
    print(top_pos_corr)
    print(f"\nTop 10 negatively correlated ingredients with {nutrient_column}:")
    print(top_neg_corr)
    print("\n")
    print("\n")
# Out:
# Top 10 positively correlated ingredients with calories:
# eggs             0.288174
# vanilla          0.258893
# flour            0.255290
# baking soda      0.211260
# sugar            0.179823
# butter           0.174787
# baking powder    0.169766
# nuts             0.148103
# pecans           0.147960
# brown sugar      0.139479
# dtype: float64
#
# Top 10 negatively correlated ingredients with calories:
# olive oil     -0.086818
# lemon juice   -0.065525
# soy sauce     -0.060330
# garlic        -0.054093
# pepper        -0.038619
# parsley       -0.035580
# onion         -0.029904
# honey         -0.029360
# tomatoes      -0.029282
# celery        -0.026236
# dtype: float64
#
#
#
#
# Top 10 positively correlated ingredients with protein_g:
# chicken           0.263254
# garlic            0.238212
# onion             0.223420
# ground beef       0.213313
# onions            0.146273
# tomatoes          0.145475
# pepper            0.144902
# cheddar cheese    0.133575
# chicken broth     0.129971
# oregano           0.126987
# dtype: float64
#
# Top 10 negatively correlated ingredients with protein_g:
# sugar           -0.231214
# vanilla         -0.157136
# baking powder   -0.088413
# cinnamon        -0.085101
# baking soda     -0.079374
# pecans          -0.075979
# pineapple       -0.072647
# nuts            -0.069524
# flour           -0.059838
# margarine       -0.046648
# dtype: float64
#
#
#
#
# Top 10 positively correlated ingredients with carbs_g:
# sugar            0.368725
# vanilla          0.336877
# flour            0.329453
# baking soda      0.299088
# eggs             0.280624
# baking powder    0.261371
# cinnamon         0.208929
# brown sugar      0.183497
# nuts             0.175908
# butter           0.163203
# dtype: float64
#
# Top 10 negatively correlated ingredients with carbs_g:
# garlic                 -0.177574
# onion                  -0.155163
# olive oil              -0.142591
# pepper                 -0.125708
# mayonnaise             -0.118506
# soy sauce              -0.106286
# parsley                -0.099885
# chicken                -0.095419
# worcestershire sauce   -0.082961
# tomatoes               -0.078852
# dtype: float64
#
#
#
#
# Top 10 positively correlated ingredients with fat_g:
# eggs              0.261521
# vanilla           0.219482
# butter            0.180632
# flour             0.175050
# pecans            0.161656
# cream cheese      0.158481
# baking soda       0.134782
# nuts              0.133980
# cheddar cheese    0.114512
# sour cream        0.112538
# dtype: float64
#
# Top 10 negatively correlated ingredients with fat_g:
# water           -0.090187
# olive oil       -0.059031
# soy sauce       -0.052108
# lemon juice     -0.047390
# honey           -0.034448
# tomatoes        -0.033699
# garlic          -0.033130
# chicken broth   -0.032132
# carrots         -0.027601
# cornstarch      -0.025848
# dtype: float64
#
#
#
#
# Top 10 positively correlated ingredients with fiber_g:
# tomatoes     0.237038
# carrots      0.180765
# onions       0.166799
# onion        0.164127
# garlic       0.158595
# potatoes     0.133445
# salt         0.118043
# celery       0.099453
# oregano      0.098249
# olive oil    0.095591
# dtype: float64
#
# Top 10 negatively correlated ingredients with fiber_g:
# cream cheese   -0.079805
# milk           -0.068174
# sugar          -0.050719
# soy sauce      -0.040186
# lemon juice    -0.036448
# egg            -0.036143
# mayonnaise     -0.030966
# vanilla        -0.027920
# pineapple      -0.027306
# cornstarch     -0.023986
# dtype: float64
#
#
#
#
# Top 10 positively correlated ingredients with sugar_g:
# sugar            0.431284
# vanilla          0.385720
# baking soda      0.247881
# eggs             0.245488
# flour            0.216488
# cinnamon         0.209493
# brown sugar      0.199270
# nuts             0.190237
# baking powder    0.188900
# pecans           0.177256
# dtype: float64
#
# Top 10 negatively correlated ingredients with sugar_g:
# garlic            -0.228988
# onion             -0.224511
# olive oil         -0.180673
# pepper            -0.156462
# parsley           -0.128712
# tomatoes          -0.127888
# chicken           -0.122784
# cheddar cheese    -0.122092
# parmesan cheese   -0.118287
# mayonnaise        -0.111087
# dtype: float64

# %% [markdown]
# # Correlation while also accounting the amount of each ingredient in each recipe New

# %%
import time
import pandas as pd
import numpy as np
import re
from fractions import Fraction

# %%
start_time = time.perf_counter()

df = pd.read_csv('data_with_nutrients_final.csv')
if 'recipe_id' not in df.columns:
    df['recipe_id'] = df.index

long = (
    df[['recipe_id','ingredients']]
      .assign(orig_ing=df['ingredients'].str.split(','))
      .explode('orig_ing')
)
long['orig_ing'] = long['orig_ing'].astype(str).str.strip()
long = long[long['orig_ing'] != '']

# %%
t_units = [
    'c','cup','cups','tbsp','tablespoon','tablespoons',
    'tsp','teaspoon','teaspoons','oz','ounce','ounces',
    'lb','pound','pounds','g','gram','grams',
    'kg','kilogram','kilograms','ml','milliliter','milliliters',
    'l','liter','liters','clove','cloves' , "lbs"
]
units_pattern = '|'.join(map(re.escape, t_units))
qty_pattern = r'(?P<qty>\d+(?:-\d+/\d+|\.\d+|/\d+)?)?'
unit_pattern = r'(?P<unit>' + units_pattern + r')?'
name_pattern = r'(?P<raw>.+)'
regex = r'^\s*' + qty_pattern + r'\s*' + unit_pattern + r'\s*' + name_pattern + r'$'

cleaned = long['orig_ing'].str.lower().str.replace(r'\(.*?\)', '', regex=True)
ex = cleaned.str.extract(regex)

# %%
def to_float(s):
    if pd.isna(s): return np.nan
    s = s.strip()
    if '-' in s and '/' in s:
        head, frac = s.split('-',1)
        try:
            return int(head) + float(Fraction(frac))
        except:
            return np.nan
    try:
        return float(Fraction(s))
    except:
        try:
            return float(s)
        except:
            return np.nan
ex['qty'] = ex['qty'].map(to_float)

# %%
STOP = set([
    'taste','chopped','sliced','minced','drained','melted','softened',
    'beaten','peeled','finely','thinly','fresh','extra','large','small','medium',
    'and','to' , "hopped" , "rinsed" , "seeded" , "diced"
])
t_forbidden = set(t_units)
forbidden = STOP.union(t_forbidden)

# %%
def clean_name(n):
    if pd.isna(n): return np.nan
    n = n.strip().lower()
    n = re.sub(r'[^\w\s]', '', n)
    n = re.sub(r'\b(?:' + units_pattern + r')\b', '', n)
    words = [w for w in n.split() if w not in forbidden and not w.isdigit()]
    if not words:
        return np.nan
    if words[-1].endswith('s') and len(words[-1]) > 1:
        words[-1] = words[-1][:-1]
    return ' '.join(words)

ex['name'] = ex['raw'].apply(clean_name)

# %%
long = long.join(ex)
long = long.dropna(subset=['name']).copy()
long['qty_filled'] = long['qty'].fillna(1)

top50 = long['name'].value_counts().nlargest(50).index
over50 = long[long['name'].isin(top50)]

X = over50.pivot_table(
    index='recipe_id',
    columns='name',
    values='qty_filled',
    aggfunc='sum',
    fill_value=0
)

nut = df.set_index('recipe_id')[[
    'calories','protein_g','carbs_g','fat_g','fiber_g','sugar_g'
]]

# %%
Xc = X - X.mean()
N = len(Xc)
print("Running correlations...")
for col in nut.columns:
    y = nut[col].reindex(Xc.index)
    yc = y - y.mean()
    ystd = y.std()
    cov = Xc.T.dot(yc) / (N - 1)
    xstd = X.std()
    corr = cov / (xstd * ystd)
    print(f"\n=== {col} ===\n")
    print("Top 10 positives:")
    print(corr.nlargest(10).to_string())
    print("\nTop 10 negatives:")
    print(corr.nsmallest(10).to_string())
    print('-'*40)

print(f"Total execution time: {time.perf_counter() - start_time:.2f} seconds")
# Out:
# Running correlations...
#
# === calories ===
#
# Top 10 positives:
# name
# egg                0.295060
# vanilla            0.230510
# baking soda        0.218181
# sugar              0.196043
# flour              0.190797
# baking powder      0.182541
# butter             0.150827
# vanilla extract    0.148967
# pecan              0.144347
# cinnamon           0.137589
#
# Top 10 negatives:
# name
# olive oil     -0.034424
# lemon juice   -0.033159
# soy sauce     -0.031717
# cilantro      -0.030025
# red onion     -0.027317
# tomatoe       -0.023178
# green onion   -0.022179
# salt pepper   -0.016715
# garlic        -0.012999
# parsley       -0.012435
# ----------------------------------------
#
# === protein_g ===
#
# Top 10 positives:
# name
# garlic                  0.242248
# ground beef             0.205431
# onion                   0.174589
# pepper                  0.156382
# chili powder            0.136516
# worcestershire sauce    0.124542
# olive oil               0.121395
# garlic powder           0.120436
# salt pepper             0.116798
# salt                    0.116418
#
# Top 10 negatives:
# name
# sugar             -0.135616
# vanilla           -0.119615
# baking powder     -0.079162
# baking soda       -0.078619
# cinnamon          -0.069638
# vanilla extract   -0.068800
# pecan             -0.061951
# ground cinnamon   -0.025463
# egg               -0.004440
# milk               0.001559
# ----------------------------------------
#
# === carbs_g ===
#
# Top 10 positives:
# name
# sugar              0.310821
# baking soda        0.300224
# vanilla            0.297361
# egg                0.290418
# baking powder      0.263241
# flour              0.219658
# cinnamon           0.215217
# vanilla extract    0.176363
# pecan              0.143877
# brown sugar        0.131285
#
# Top 10 negatives:
# name
# garlic                 -0.125850
# olive oil              -0.097398
# mayonnaise             -0.092376
# pepper                 -0.092028
# salt pepper            -0.077644
# soy sauce              -0.071969
# parsley                -0.070833
# onion                  -0.067759
# green onion            -0.064304
# worcestershire sauce   -0.064064
# ----------------------------------------
#
# === fat_g ===
#
# Top 10 positives:
# name
# egg                0.251732
# vanilla            0.185221
# pecan              0.150262
# butter             0.142801
# baking soda        0.142372
# flour              0.131905
# vanilla extract    0.129000
# sugar              0.118393
# baking powder      0.114333
# sour cream         0.103532
#
# Top 10 negatives:
# name
# cilantro      -0.032662
# soy sauce     -0.030192
# olive oil     -0.021996
# water         -0.019482
# tomatoe       -0.019087
# lemon juice   -0.017562
# red onion     -0.017059
# carrot        -0.015719
# honey         -0.012879
# garlic        -0.009537
# ----------------------------------------
#
# === fiber_g ===
#
# Top 10 positives:
# name
# garlic          0.203190
# chili powder    0.163289
# onion           0.160188
# salt            0.158479
# olive oil       0.134405
# tomatoe         0.122904
# green pepper    0.101460
# cilantro        0.097487
# ground beef     0.095019
# red onion       0.084543
#
# Top 10 negatives:
# name
# vanilla            -0.012159
# soy sauce          -0.011207
# mayonnaise         -0.010615
# cornstarch         -0.006805
# milk                0.000721
# lemon juice         0.001957
# egg                 0.005805
# vanilla extract     0.007097
# sugar               0.007244
# allpurpose flour    0.013100
# ----------------------------------------
#
# === sugar_g ===
#
# Top 10 positives:
# name
# sugar              0.337812
# vanilla            0.330374
# baking soda        0.253787
# egg                0.223532
# cinnamon           0.201480
# baking powder      0.201335
# vanilla extract    0.189449
# pecan              0.164564
# flour              0.154943
# brown sugar        0.136963
#
# Top 10 negatives:
# name
# garlic          -0.184454
# olive oil       -0.142990
# pepper          -0.127303
# onion           -0.119385
# salt pepper     -0.109596
# parsley         -0.102131
# mayonnaise      -0.093551
# green onion     -0.088786
# garlic powder   -0.076296
# mushroom        -0.075243
# ----------------------------------------
# Total execution time: 31.10 seconds
